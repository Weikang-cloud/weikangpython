# %%
k = 2
m = 2
n = 2
N = k + m + n

# %% [markdown]
# k*(k+4*m-1)+m*(3*m+n)/16*N(N-1)

# %%
s = (k*(k+4*m-1)+m*(3*m+n)-3)/(16*N*(N-1))
print(s)
# Out:
# 0.06458333333333334

# %%
S = k/N+(4*k*m+3*m**2-3*m+2*m*n)/(4*N*(N-1))+(m*n+2*k*n+m*n)/(2*N*(N-1))
print(S)
# Out:
# 0.8499999999999999

# %%
X = k*(k-1+m+n)/(N*(N-1)) + m/(N*(N-1))/((4*k+3*m+2*n-3)/4)+(n/(N*(N-1))*(2*k+m)/2)
print(X)
# Out:
# 0.5511111111111111

# %%
Z = (k/N)*(k-1)/(N-1) + (k/N)*m(N-1) +k/N*(m/(N-1))+m/N*
