# %%
k = 28
m = 21
n = 21
N = k + m + n

# %% [markdown]
# k*(k+4*m-1)+m*(3*m+n)/16*N(N-1)

# %%
#s = (k*(k+4*m-1)+m*(3*m+n)-3)/(16*N*(N-1))
print(s)
# Out:
# 0.05531113933236575

# %%
#S = k/N+(4*k*m+3*m**2-3*m+2*m*n)/(4*N*(N-1))+(m*n+2*k*n+m*n)/(2*N*(N-1))
print(S)
# Out:
# 0.8051523947750362

# %%
X = (k*(N-1) + m*(k + 0.75*(m-1) + 0.5*n) + n*(k + 0.5*m)) / (N*(N-1))
print(X)
# Out:
# 0.8
