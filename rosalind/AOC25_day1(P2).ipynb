# %%
start_position = 50
times_of_zero = 0
for dial in input_list:
    direction = dial[0]
    step = int(dial[1:])
    for a in range(step):
        if direction == 'L':
            start_position =start_position - 1
        if direction == 'R':
            start_position = start_position + 1
        if start_position < 0:
            start_position = 99
        elif start_position > 99:
            start_position = 0
        if start_position == 0:
            times_of_zero = times_of_zero + 1

print(times_of_zero)
# Out:
# 7199
