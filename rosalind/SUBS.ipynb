# %%
s = 'GATATATGCATATACTT'
sub_s = 'ATAT'
position = []
for real_i in range(len(s)):
    print(real_i, s[real_i])
# Out:
# 0 G
# 1 A
# 2 T
# 3 A
# 4 T
# 5 A
# 6 T
# 7 G
# 8 C
# 9 A
# 10 T
# 11 A
# 12 T
# 13 A
# 14 C
# 15 T
# 16 T

# %%
print(s[2:4])
# Out:
# TA

# %%
s = "..."
t = "GGTACAAGG"

position = []

for i in range(len(s)):
    piece = s[i : i+len(t)]
    if piece == t:
        position.append(i + 1)

print(position)
# Out:
# [7, 42, 99, 107, 122, 129, 187, 226, 261, 277, 295, 324, 339, 355, 380, 399, 446, 518, 542, 669, 691, 707, 722, 769, 776, 783, 817, 856]
