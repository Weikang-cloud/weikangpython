# %%
s = '434234234234278'
print(len(s))
# Out:
# 15
# 43423

# %%
a = (max(s[:(len(s)-11)]))
print(a)
print(s.index(a))
b = max(s[int(s.index(a))+1:len(s)-10])
print(b)
print(s.index(b))
print(s[int(s.index(a))+1])
# Out:
# 4
# 0
# 4
# 0
# 3

# %%
b = max(s[int(s.index(a))+1:len(s)-10])
print(b)
print(s.index(b))
print(s[int(s.index(a))+1])
# Out:
# 4
# 0
# 3

# %%
c = max(s[int(s.index(b))+1:len(s)-9])
print(c)
print(s.index(c))
# Out:
# 4
# 0

# %%
d = max(s[int(s.index(c))+1:len(s)-8])
print(d)
print(s[int(s.index(c))+1])
# Out:
# 4
# 3

# %%
e = max(s[int(s.index(d))+1:len(s)-7])
print(e)
# Out:
# 4

# %%
f = max(s[int(s.index(e))+1:len(s)-6])
print(f)
# Out:
# 4

# %%
g = max(s[int(s.index(f))+1:len(s)-5])
print(g)
# Out:
# 4
