# %%
overall_id = []
valid_range = []
food_id = []
with open('day5.txt') as file:
    for l in file:
        range_str = l.strip()
        if len(range_str) > 20:
            valid_range.append(range_str)
        else:
            food_id.append(range_str)


food_id = food_id[1:]

            
            
print(food_id[:10])
# Out:
# ['278402555432346', '132663185371131', '308642641112043', '33559341434412', '405303123438474', '485951992574145', '313064131630188', '260158596036936', '88167936209309', '172542568004197']

# %%
valid_numbers = []
for i in valid_range:
    i = (i)
    a, b = i.split('-')
    valid_numbers.append((int(a),int(b)+1))

# %%
answer = 0
final_answer = []
for j in valid_numbers:
    a,b = j
    for i in food_id:
        i = int(i)
        #print(new_i)
        if i in range(a, b):
            final_answer.append(i)
    else:
        continue

# %%
count = 0
for i in list(set(final_answer)):
    count += 1
print(count)
# Out:
# 563
